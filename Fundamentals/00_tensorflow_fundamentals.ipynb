# %% [markdown]
# <a href="https://colab.research.google.com/github/juliansangillo/tensorflow-deep-learning-bootcamp/blob/main/Fundamentals/00_tensorflow_fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # In this notebook, we're going to cover some of the most fundamental concepts of tensors using TensorFlow
#
# More specifically, we're going to cover:
# - Introduction to tensors
# - Getting information from tensors
# - Manipulating tensors
# - Tensors & NumPy
# - Using @tf.function (a way to speed up your regular Python functions)
# - Using GPUs with TensorFlow (or TPUs)
# - Exercises to try for yourself!

# %% [markdown]
# # Introduction to Tensors
